# %%
import pandas as pd
import re
from urllib.parse import urlparse


df_user_reviews = pd.read_csv('UserReviews.txt', delimiter='\t', encoding='ISO-8859-1')
df_meta = pd.read_csv('metaClean43Brightspace.txt', delimiter='\t', encoding='ISO-8859-1')
df_MovieID = pd.read_csv('NewMovieTable.csv', encoding='ISO-8859-1')


df_reviews_only = df_user_reviews[df_user_reviews['Rev'].notna() & (df_user_reviews['Rev'].str.strip() != '')]


df_reviews_only = df_reviews_only.drop_duplicates()


columns_to_drop = [
    "WC", "Analytic", "Clout", "Authentic", "Tone", "WPS", "Sixltr", "Dic", 
    "function", "pronoun", "ppron", "i", "we", "you", "shehe", "they", "ipron", 
    "article", "prep", "auxverb", "adverb", "conj", "negate", "verb", "adj", 
    "compare", "interrog", "number", "quant", "affect", 
    "anx", "anger", "sad", "social", "family", "friend", "female", "male", 
    "cogproc", "insight", "cause", "discrep", "tentat", "certain", "differ", 
    "percept", "see", "hear", "feel", "bio", "body", "health", "sexual", 
    "ingest", "drives", "affiliation", "achieve", "power", "reward", "risk", 
    "focuspast", "focuspresent", "focusfuture", "relativ", "motion", "space", 
    "time", "work", "leisure", "home", "money", "relig", "death", "informal", 
    "swear", "netspeak", "assent", "nonflu", "filler", "AllPunc", "Period", 
    "Comma", "Colon", "SemiC", "QMark", "Exclam", "Dash", "Quote", "Apostro", 
    "Parenth", "OtherP", "dateP"
]
df_reviews_only = df_reviews_only.drop(columns=columns_to_drop, errors='ignore')


df_reviews_only.rename(columns={'thumbstot': 'totalthumbs'}, inplace=True)


df_reviews_only['reviewer'] = df_reviews_only['reviewer'].str.replace("'", "").str.replace(".", "").str.lower()


def extract_title_from_url(url):
    path = urlparse(url).path
    title = path.split('/')[-1]
    return title.replace('-', ' ').lower().strip()

df_reviews_only['extracted_title'] = df_reviews_only['url'].apply(extract_title_from_url)


def clean_text(text):
    if pd.isna(text):
        return ''
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

df_reviews_only['normalized_title'] = df_reviews_only['extracted_title'].apply(clean_text)
df_MovieID['normalized_title'] = df_MovieID['TITLE'].apply(clean_text)


df_reviews_only['review_id'] = range(1, len(df_reviews_only) + 1)


df_reviews_only = df_reviews_only.merge(df_MovieID[['normalized_title', 'Movie_ID']], on='normalized_title', how='left')


if 'ID' in df_reviews_only.columns:
    df_reviews_only.rename(columns={'ID': 'Movie_ID'}, inplace=True)


df_reviews_only['posemo'] = df_reviews_only['posemo'].astype(str).str.replace(',', '.').astype(float)
df_reviews_only['negemo'] = df_reviews_only['negemo'].astype(str).str.replace(',', '.').astype(float)


unmatched_reviews = df_reviews_only[df_reviews_only['Movie_ID'].isna()]
if not unmatched_reviews.empty:
    print("Unmatched user reviews:")
    print(unmatched_reviews[['url', 'normalized_title']])


df_reviews_only.to_csv('/Users/laiba/Documents/GitHub/gbm/cleaned_user_reviews.csv', index=False)


print("After merge, columns are:", df_reviews_only.columns)
print(df_reviews_only.head())
# Out:
# /var/folders/l3/5c9wkk49081bn1c_8j1b6yq00000gn/T/ipykernel_67356/2580579192.py:6: DtypeWarning: Columns (1,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_user_reviews = pd.read_csv('UserReviews.txt', delimiter='\t', encoding='ISO-8859-1')
# After merge, columns are: Index(['url', 'idvscore', 'reviewer', 'Rev', 'thumbsUp', 'thumbsTot', 'posemo',
#        'negemo', 'extracted_title', 'normalized_title', 'review_id',
#        'Movie_ID'],
#       dtype='object')
#                                         url idvscore       reviewer  \
# 0  https://www.metacritic.com/movie/bronson      8.0   longbottom94
# 1  https://www.metacritic.com/movie/bronson      9.0        martinb
# 2  https://www.metacritic.com/movie/bronson     10.0         jaakko
# 3  https://www.metacritic.com/movie/bronson      6.0          capor
# 4  https://www.metacritic.com/movie/bronson      8.0        orwellb
#
#                                                  Rev thumbsUp thumbsTot  \
# 0   'Many have dismissed this film for not explor...      2.0       2.0
# 1   'Anyone who doesn t like this movie simply ju...      0.0       1.0
# 2   'Not sure what to think at this film at first...      1.0       1.0
# 3   'Nicely portrayed but it lacks the elements t...      0.0       1.0
# 4   'Bronson is more than entertainment. It is ar...      0.0       0.0
#
#    posemo  negemo extracted_title normalized_title  review_id  Movie_ID
# 0    0.00    0.88         bronson          bronson          1     19419
# 1    2.91    0.97         bronson          bronson          2     19419
# 2    4.20    0.70         bronson          bronson          3     19419
# 3   14.29    0.00         bronson          bronson          4     19419
# 4    5.00    0.00         bronson          bronson          5     19419

# %%
print(df_reviews_only.columns)
# Out:
# Index(['url', 'idvscore', 'reviewer', 'Rev', 'thumbsUp', 'thumbsTot', 'posemo',
#        'negemo', 'extracted_title', 'normalized_title', 'review_id',
#        'Movie_ID'],
#       dtype='object')

# %%
print(df_reviews_only[['thumbsTot', 'thumbsUp']].isna().sum())
# Out:
# thumbsTot    0
# thumbsUp     0
# dtype: int64

# %%
max_bigint = 9223372036854775807

# Rename 'thumbsTot' to 'totalthumbs' and 'thumbsUp' to 'thumbsup'
df_reviews_only.rename(columns={'thumbsTot': 'totalthumbs', 'thumbsUp': 'thumbsup'}, inplace=True)

# Ensure you're using the correct column names
df_reviews_only['totalthumbs'] = pd.to_numeric(df_reviews_only['totalthumbs'], errors='coerce')
df_reviews_only['thumbsup'] = pd.to_numeric(df_reviews_only['thumbsup'], errors='coerce')

# Apply modulo to ensure values stay within the bigint range
df_reviews_only['totalthumbs'] = df_reviews_only['totalthumbs'].apply(lambda x: x % max_bigint if pd.notna(x) else x)
df_reviews_only['thumbsup'] = df_reviews_only['thumbsup'].apply(lambda x: x % max_bigint if pd.notna(x) else x)
df_reviews_only['review_id'] = df_reviews_only['review_id'].apply(lambda x: x % max_bigint if pd.notna(x) else x)
df_reviews_only['Movie_ID'] = df_reviews_only['Movie_ID'].apply(lambda x: x % max_bigint if pd.notna(x) else x)

# Print the max values to check for outliers
print("Max Movie_ID:", df_reviews_only['Movie_ID'].max())
print("Max review_id:", df_reviews_only['review_id'].max())
print("Max totalthumbs:", df_reviews_only['totalthumbs'].max())
print("Max thumbsup:", df_reviews_only['thumbsup'].max())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'totalthumbs'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 4
#       1 max_bigint = 9223372036854775807
#       3 # Ensure you're using the correct column names
# ----> 4 df_reviews_only['totalthumbs'] = pd.to_numeric(df_reviews_only['totalthumbs'], errors='coerce')
#       5 df_reviews_only['thumbsup'] = pd.to_numeric(df_reviews_only['thumbsup'], errors='coerce')
#       7 # Apply modulo to ensure values stay within the bigint range
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'totalthumbs'

# %%
import psycopg2

# Step 1: Connect to PostgreSQL
conn = psycopg2.connect(
    host="localhost",
    database="postgres",
    user="postgres",
    password="Laiba786",
    port="5432"
)
cursor = conn.cursor()

# Step 2: Create Tables if not exists
create_movie_table_query = """
CREATE TABLE IF NOT EXISTS movie_table (
    Movie_ID SERIAL PRIMARY KEY,
    Title TEXT UNIQUE,   -- Ensure title is unique
    WorldwideBoxOffice FLOAT
);
"""
create_user_reviews_query = """
CREATE TABLE IF NOT EXISTS user_reviews (
    review_id SERIAL PRIMARY KEY,
    reviewscore FLOAT,
    posemo FLOAT,
    negemo FLOAT,
    totalthumbs INTEGER,
    thumbsup INTEGER,
    rev TEXT,
    url TEXT,
    movie_id BIGINT REFERENCES movie_table (Movie_ID)
);
"""

cursor.execute(create_movie_table_query)
cursor.execute(create_user_reviews_query)
conn.commit()

# Step 3: Insert Queries
insert_movie_query = """
INSERT INTO movie_table (Title, WorldwideBoxOffice)
VALUES (%s, %s)
RETURNING Movie_ID;
"""
insert_user_reviews_query = """
INSERT INTO user_reviews (review_id, movie_id, reviewscore, posemo, negemo, totalthumbs, thumbsup, rev, url)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
ON CONFLICT (review_id) DO NOTHING;
"""




# Insert Data into Tables
for index, row in df_reviews_only.iterrows():
    try:
        # Step 4a: Check if the movie already exists by title
        cursor.execute("SELECT Movie_ID FROM movie_table WHERE Title = %s", (row['extracted_title'],))
        existing_movie = cursor.fetchone()

        if existing_movie:
            movie_id = existing_movie[0]  # Get the existing Movie_ID
        else:
            # Insert the movie if it doesn't exist, returning Movie_ID
            cursor.execute(insert_movie_query, (row['extracted_title'], None))
            movie_id = cursor.fetchone()[0]  # Get the newly generated Movie_ID

        # Debug print before insertion
        print(f"Inserting review_id: {row['review_id']}, movie_id: {movie_id}, thumbsTot: {row['thumbsTot']}, thumbsUp: {row['thumbsUp']}")
        
        # Step 4b: Insert into user_reviews
        cursor.execute(insert_user_reviews_query, (
            row['review_id'], movie_id, row['idvscore'], row['posemo'], row['negemo'],
            row['thumbsTot'], row['thumbsUp'], row['Rev'], row['url']
        ))
        
    except Exception as e:
        print(f"Error on row {index}: {e}")
        break 
    

conn.commit()

# Step 6: Check the columns in user_reviews table
cursor.execute("""
    SELECT column_name, data_type
    FROM information_schema.columns
    WHERE table_name = 'user_reviews';
""")
columns_info = cursor.fetchall()
for column in columns_info:
    print(column)

# Step 7: Close the cursor and connection
cursor.close()
conn.close()

print("Data inserted and schema retrieved successfully!")
# Out:
# Inserting review_id: 1, movie_id: 20029, thumbsTot: 2.0, thumbsUp: 2.0
# Inserting review_id: 2, movie_id: 20029, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 3, movie_id: 20029, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 4, movie_id: 20029, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 5, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 6, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 7, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 8, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 9, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 10, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 11, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 12, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 13, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 14, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 15, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 16, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 17, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 18, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 19, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 20, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 21, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 22, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 23, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 24, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 25, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 26, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 27, movie_id: 20029, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 28, movie_id: 15066, thumbsTot: 3.0, thumbsUp: 0.0
# Inserting review_id: 29, movie_id: 15066, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 30, movie_id: 32883, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 30, movie_id: 32883, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 31, movie_id: 32883, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 31, movie_id: 32883, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 32, movie_id: 32883, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 32, movie_id: 32883, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 33, movie_id: 11315, thumbsTot: 3.0, thumbsUp: 3.0
# Inserting review_id: 34, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 35, movie_id: 11315, thumbsTot: 12.0, thumbsUp: 11.0
# Inserting review_id: 36, movie_id: 11315, thumbsTot: 6.0, thumbsUp: 3.0
# Inserting review_id: 37, movie_id: 11315, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 38, movie_id: 11315, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 39, movie_id: 11315, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 40, movie_id: 11315, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 41, movie_id: 11315, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 42, movie_id: 11315, thumbsTot: 9.0, thumbsUp: 3.0
# Inserting review_id: 43, movie_id: 11315, thumbsTot: 6.0, thumbsUp: 1.0
# Inserting review_id: 44, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 45, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 46, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 47, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 48, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 49, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 50, movie_id: 11315, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 51, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 52, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 53, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 54, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 55, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 56, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 57, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 58, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 59, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 60, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 61, movie_id: 11315, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 62, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 63, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 64, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 65, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 66, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 67, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 68, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 69, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 70, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 71, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 72, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 73, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 74, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 75, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 76, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 77, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 78, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 79, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 80, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 81, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 82, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 83, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 84, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 85, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 86, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 87, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 88, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 89, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 90, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 91, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 92, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 93, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 94, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 95, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 96, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 97, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 98, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 99, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 100, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 101, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 102, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 103, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 104, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 105, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 106, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 107, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 108, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 109, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 110, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 111, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 112, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 113, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 114, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 115, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 116, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 117, movie_id: 11315, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 118, movie_id: 21956, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 119, movie_id: 21956, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 120, movie_id: 21956, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 121, movie_id: 17891, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 122, movie_id: 17891, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 123, movie_id: 17891, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 124, movie_id: 17152, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 125, movie_id: 17152, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 126, movie_id: 17152, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 127, movie_id: 17152, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 128, movie_id: 7789, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 128, movie_id: 7789, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 129, movie_id: 7789, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 129, movie_id: 7789, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 130, movie_id: 7789, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 130, movie_id: 7789, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 131, movie_id: 6653, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 132, movie_id: 6653, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 133, movie_id: 34353, thumbsTot: 3.0, thumbsUp: 3.0
# Inserting review_id: 133, movie_id: 34353, thumbsTot: 3.0, thumbsUp: 3.0
# Inserting review_id: 134, movie_id: 34353, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 134, movie_id: 34353, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 135, movie_id: 34353, thumbsTot: 5.0, thumbsUp: 4.0
# Inserting review_id: 135, movie_id: 34353, thumbsTot: 5.0, thumbsUp: 4.0
# Inserting review_id: 136, movie_id: 34353, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 136, movie_id: 34353, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 137, movie_id: 34353, thumbsTot: 5.0, thumbsUp: 3.0
# Inserting review_id: 137, movie_id: 34353, thumbsTot: 5.0, thumbsUp: 3.0
# Inserting review_id: 138, movie_id: 34353, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 138, movie_id: 34353, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 139, movie_id: 34353, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 139, movie_id: 34353, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 140, movie_id: 34353, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 140, movie_id: 34353, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 141, movie_id: 34353, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 141, movie_id: 34353, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 142, movie_id: 34353, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 142, movie_id: 34353, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 143, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 143, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 144, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 144, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 145, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 145, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 146, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 146, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 147, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 147, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 148, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 148, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 149, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 149, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 150, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 150, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 151, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 151, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 152, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 152, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 153, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 153, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 154, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 154, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 155, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 155, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 156, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 156, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 157, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 157, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 158, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 158, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 159, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 159, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 160, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 160, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 161, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 161, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 162, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 162, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 163, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 163, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 164, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 164, movie_id: 34353, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 165, movie_id: 16089, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 166, movie_id: 34354, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 167, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 168, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 169, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 170, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 171, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 172, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 173, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 174, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 175, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 176, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 177, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 178, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 179, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 180, movie_id: 34354, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 181, movie_id: 15410, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 182, movie_id: 15079, thumbsTot: 2.0, thumbsUp: 2.0
# Inserting review_id: 183, movie_id: 15079, thumbsTot: 2.0, thumbsUp: 2.0
# Inserting review_id: 184, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 185, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 186, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 187, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 188, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 189, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 190, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 191, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 192, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 193, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 194, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 195, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 196, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 197, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 198, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 199, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 200, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 201, movie_id: 15079, thumbsTot: 4.0, thumbsUp: 3.0
# Inserting review_id: 202, movie_id: 15079, thumbsTot: 9.0, thumbsUp: 6.0
# Inserting review_id: 203, movie_id: 15079, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 204, movie_id: 15079, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 205, movie_id: 15079, thumbsTot: 5.0, thumbsUp: 3.0
# Inserting review_id: 206, movie_id: 15079, thumbsTot: 6.0, thumbsUp: 3.0
# Inserting review_id: 207, movie_id: 15079, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 208, movie_id: 15079, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 209, movie_id: 15079, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 210, movie_id: 15079, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 211, movie_id: 15079, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 212, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 213, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 214, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 215, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 216, movie_id: 15079, thumbsTot: 3.0, thumbsUp: 0.0
# Inserting review_id: 217, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 218, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 219, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 220, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 221, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 222, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 223, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 224, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 225, movie_id: 15079, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 226, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 227, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 228, movie_id: 15079, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 229, movie_id: 15079, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 230, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 231, movie_id: 15079, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 232, movie_id: 15079, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 233, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 234, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 235, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 236, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 237, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 238, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 239, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 240, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 241, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 242, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 243, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 244, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 245, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 246, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 247, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 248, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 249, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 250, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 251, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 252, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 253, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 254, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 255, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 256, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 257, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 258, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 259, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 260, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 261, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 262, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 263, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 264, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 265, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 266, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 267, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 268, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 269, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 270, movie_id: 15079, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 271, movie_id: 14789, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 272, movie_id: 14789, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 273, movie_id: 14789, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 274, movie_id: 14789, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 275, movie_id: 14789, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 276, movie_id: 14789, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 277, movie_id: 21775, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 278, movie_id: 21775, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 279, movie_id: 21775, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 280, movie_id: 21775, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 281, movie_id: 21775, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 282, movie_id: 21775, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 283, movie_id: 21775, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 284, movie_id: 21775, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 285, movie_id: 21775, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 286, movie_id: 21775, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 287, movie_id: 21775, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 288, movie_id: 21775, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 289, movie_id: 18577, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 290, movie_id: 18577, thumbsTot: 0.0, thumbsUp: 0.0
# Inserting review_id: 291, movie_id: 31225, thumbsTot: 67.0, thumbsUp: 48.0
# Inserting review_id: 291, movie_id: 31225, thumbsTot: 67.0, thumbsUp: 48.0
# Inserting review_id: 292, movie_id: 31225, thumbsTot: 96.0, thumbsUp: 18.0
# Inserting review_id: 292, movie_id: 31225, thumbsTot: 96.0, thumbsUp: 18.0
# Inserting review_id: 293, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 5.0
# Inserting review_id: 293, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 5.0
# Inserting review_id: 294, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 4.0
# Inserting review_id: 294, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 4.0
# Inserting review_id: 295, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 3.0
# Inserting review_id: 295, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 3.0
# Inserting review_id: 296, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 2.0
# Inserting review_id: 296, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 2.0
# Inserting review_id: 297, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 2.0
# Inserting review_id: 297, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 2.0
# Inserting review_id: 298, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 2.0
# Inserting review_id: 298, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 2.0
# Inserting review_id: 299, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 2.0
# Inserting review_id: 299, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 2.0
# Inserting review_id: 300, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 2.0
# Inserting review_id: 300, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 2.0
# Inserting review_id: 301, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 301, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 302, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 302, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 303, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 303, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 304, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 304, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 305, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 305, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 306, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 306, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 307, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 307, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 308, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 308, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 309, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 309, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 310, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 310, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 311, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 311, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 312, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 312, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 313, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 313, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 314, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 314, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 315, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 315, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 316, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 316, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 1.0
# Inserting review_id: 317, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 4.0
# Inserting review_id: 317, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 4.0
# Inserting review_id: 318, movie_id: 31225, thumbsTot: 9.0, thumbsUp: 7.0
# Inserting review_id: 318, movie_id: 31225, thumbsTot: 9.0, thumbsUp: 7.0
# Inserting review_id: 319, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 3.0
# Inserting review_id: 319, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 3.0
# Inserting review_id: 320, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 3.0
# Inserting review_id: 320, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 3.0
# Inserting review_id: 321, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 3.0
# Inserting review_id: 321, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 3.0
# Inserting review_id: 322, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 3.0
# Inserting review_id: 322, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 3.0
# Inserting review_id: 323, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 3.0
# Inserting review_id: 323, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 3.0
# Inserting review_id: 324, movie_id: 31225, thumbsTot: 19.0, thumbsUp: 14.0
# Inserting review_id: 324, movie_id: 31225, thumbsTot: 19.0, thumbsUp: 14.0
# Inserting review_id: 325, movie_id: 31225, thumbsTot: 11.0, thumbsUp: 8.0
# Inserting review_id: 325, movie_id: 31225, thumbsTot: 11.0, thumbsUp: 8.0
# Inserting review_id: 326, movie_id: 31225, thumbsTot: 10.0, thumbsUp: 7.0
# Inserting review_id: 326, movie_id: 31225, thumbsTot: 10.0, thumbsUp: 7.0
# Inserting review_id: 327, movie_id: 31225, thumbsTot: 16.0, thumbsUp: 11.0
# Inserting review_id: 327, movie_id: 31225, thumbsTot: 16.0, thumbsUp: 11.0
# Inserting review_id: 328, movie_id: 31225, thumbsTot: 12.0, thumbsUp: 8.0
# Inserting review_id: 328, movie_id: 31225, thumbsTot: 12.0, thumbsUp: 8.0
# Inserting review_id: 329, movie_id: 31225, thumbsTot: 9.0, thumbsUp: 6.0
# Inserting review_id: 329, movie_id: 31225, thumbsTot: 9.0, thumbsUp: 6.0
# Inserting review_id: 330, movie_id: 31225, thumbsTot: 6.0, thumbsUp: 4.0
# Inserting review_id: 330, movie_id: 31225, thumbsTot: 6.0, thumbsUp: 4.0
# Inserting review_id: 331, movie_id: 31225, thumbsTot: 6.0, thumbsUp: 4.0
# Inserting review_id: 331, movie_id: 31225, thumbsTot: 6.0, thumbsUp: 4.0
# Inserting review_id: 332, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 332, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 333, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 333, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 334, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 334, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 335, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 335, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 336, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 336, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 337, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 337, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 338, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 338, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 339, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 339, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 340, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 340, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 341, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 341, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 342, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 342, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 343, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 343, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 344, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 344, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 345, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 345, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 346, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 346, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 347, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 347, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 348, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 348, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 349, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 349, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 2.0
# Inserting review_id: 350, movie_id: 31225, thumbsTot: 11.0, thumbsUp: 7.0
# Inserting review_id: 350, movie_id: 31225, thumbsTot: 11.0, thumbsUp: 7.0
# Inserting review_id: 351, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 3.0
# Inserting review_id: 351, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 3.0
# Inserting review_id: 352, movie_id: 31225, thumbsTot: 17.0, thumbsUp: 10.0
# Inserting review_id: 352, movie_id: 31225, thumbsTot: 17.0, thumbsUp: 10.0
# Inserting review_id: 353, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 4.0
# Inserting review_id: 353, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 4.0
# Inserting review_id: 354, movie_id: 31225, thumbsTot: 13.0, thumbsUp: 7.0
# Inserting review_id: 354, movie_id: 31225, thumbsTot: 13.0, thumbsUp: 7.0
# Inserting review_id: 355, movie_id: 31225, thumbsTot: 12.0, thumbsUp: 6.0
# Inserting review_id: 355, movie_id: 31225, thumbsTot: 12.0, thumbsUp: 6.0
# Inserting review_id: 356, movie_id: 31225, thumbsTot: 8.0, thumbsUp: 4.0
# Inserting review_id: 356, movie_id: 31225, thumbsTot: 8.0, thumbsUp: 4.0
# Inserting review_id: 357, movie_id: 31225, thumbsTot: 8.0, thumbsUp: 4.0
# Inserting review_id: 357, movie_id: 31225, thumbsTot: 8.0, thumbsUp: 4.0
# Inserting review_id: 358, movie_id: 31225, thumbsTot: 6.0, thumbsUp: 3.0
# Inserting review_id: 358, movie_id: 31225, thumbsTot: 6.0, thumbsUp: 3.0
# Inserting review_id: 359, movie_id: 31225, thumbsTot: 6.0, thumbsUp: 3.0
# Inserting review_id: 359, movie_id: 31225, thumbsTot: 6.0, thumbsUp: 3.0
# Inserting review_id: 360, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 2.0
# Inserting review_id: 360, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 2.0
# Inserting review_id: 361, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 2.0
# Inserting review_id: 361, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 2.0
# Inserting review_id: 362, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 2.0
# Inserting review_id: 362, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 2.0
# Inserting review_id: 363, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 2.0
# Inserting review_id: 363, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 2.0
# Inserting review_id: 364, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 364, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 365, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 365, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 366, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 366, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 367, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 367, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 368, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 368, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 369, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 369, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 370, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 370, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 371, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 371, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 372, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 372, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 373, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 373, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 374, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 374, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 375, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 375, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 376, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 376, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 377, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 377, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 378, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 378, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 379, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 379, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 380, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 380, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 381, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 381, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 382, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 382, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 383, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 383, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 384, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 384, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 385, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 385, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 386, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 386, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 387, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 387, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 388, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 388, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 389, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 389, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 390, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 390, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 391, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 391, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 392, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 392, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 393, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 393, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 394, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 394, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 395, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 395, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 396, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 396, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 397, movie_id: 31225, thumbsTot: 11.0, thumbsUp: 5.0
# Inserting review_id: 397, movie_id: 31225, thumbsTot: 11.0, thumbsUp: 5.0
# Inserting review_id: 398, movie_id: 31225, thumbsTot: 18.0, thumbsUp: 8.0
# Inserting review_id: 398, movie_id: 31225, thumbsTot: 18.0, thumbsUp: 8.0
# Inserting review_id: 399, movie_id: 31225, thumbsTot: 9.0, thumbsUp: 4.0
# Inserting review_id: 399, movie_id: 31225, thumbsTot: 9.0, thumbsUp: 4.0
# Inserting review_id: 400, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 3.0
# Inserting review_id: 400, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 3.0
# Inserting review_id: 401, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 3.0
# Inserting review_id: 401, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 3.0
# Inserting review_id: 402, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 3.0
# Inserting review_id: 402, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 3.0
# Inserting review_id: 403, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 3.0
# Inserting review_id: 403, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 3.0
# Inserting review_id: 404, movie_id: 31225, thumbsTot: 10.0, thumbsUp: 4.0
# Inserting review_id: 404, movie_id: 31225, thumbsTot: 10.0, thumbsUp: 4.0
# Inserting review_id: 405, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 405, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 406, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 406, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 407, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 407, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 408, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 408, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 409, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 409, movie_id: 31225, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 410, movie_id: 31225, thumbsTot: 11.0, thumbsUp: 4.0
# Inserting review_id: 410, movie_id: 31225, thumbsTot: 11.0, thumbsUp: 4.0
# Inserting review_id: 411, movie_id: 31225, thumbsTot: 30.0, thumbsUp: 10.0
# Inserting review_id: 411, movie_id: 31225, thumbsTot: 30.0, thumbsUp: 10.0
# Inserting review_id: 412, movie_id: 31225, thumbsTot: 9.0, thumbsUp: 3.0
# Inserting review_id: 412, movie_id: 31225, thumbsTot: 9.0, thumbsUp: 3.0
# Inserting review_id: 413, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 413, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 414, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 414, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 415, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 415, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 416, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 416, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 417, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 417, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 418, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 418, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 419, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 419, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 420, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 420, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 421, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 421, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 422, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 422, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 423, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 423, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 424, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 424, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 425, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 425, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 426, movie_id: 31225, thumbsTot: 10.0, thumbsUp: 3.0
# Inserting review_id: 426, movie_id: 31225, thumbsTot: 10.0, thumbsUp: 3.0
# Inserting review_id: 427, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 2.0
# Inserting review_id: 427, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 2.0
# Inserting review_id: 428, movie_id: 31225, thumbsTot: 15.0, thumbsUp: 4.0
# Inserting review_id: 428, movie_id: 31225, thumbsTot: 15.0, thumbsUp: 4.0
# Inserting review_id: 429, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 429, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 430, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 430, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 431, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 431, movie_id: 31225, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 432, movie_id: 31225, thumbsTot: 42.0, thumbsUp: 7.0
# Inserting review_id: 432, movie_id: 31225, thumbsTot: 42.0, thumbsUp: 7.0
# Inserting review_id: 433, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 1.0
# Inserting review_id: 433, movie_id: 31225, thumbsTot: 7.0, thumbsUp: 1.0
# Inserting review_id: 434, movie_id: 31225, thumbsTot: 8.0, thumbsUp: 1.0
# Inserting review_id: 434, movie_id: 31225, thumbsTot: 8.0, thumbsUp: 1.0
# Inserting review_id: 435, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 435, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 436, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 436, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 437, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 0.0
# Inserting review_id: 437, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 0.0
# Inserting review_id: 438, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 438, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 439, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 0.0
# Inserting review_id: 439, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 0.0
# Inserting review_id: 440, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 440, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 441, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 441, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 442, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 442, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 443, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 443, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 444, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 444, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 445, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 445, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 446, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 446, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 447, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 447, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 448, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 448, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 449, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 449, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 450, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 450, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 451, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 451, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 452, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 452, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 453, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 0.0
# Inserting review_id: 453, movie_id: 31225, thumbsTot: 3.0, thumbsUp: 0.0
# Inserting review_id: 454, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 454, movie_id: 31225, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 455, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 455, movie_id: 31225, thumbsTot: 2.0, thumbsUp: 0.0
# ...
# Inserting review_id: 4434, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4434, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4435, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4435, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4436, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4436, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4437, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4437, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4438, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4438, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4439, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4439, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4440, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4440, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4441, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4441, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4442, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4442, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 1.0
# Inserting review_id: 4443, movie_id: 34041, thumbsTot: 11.0, thumbsUp: 5.0
# Inserting review_id: 4443, movie_id: 34041, thumbsTot: 11.0, thumbsUp: 5.0
# Inserting review_id: 4444, movie_id: 34041, thumbsTot: 11.0, thumbsUp: 5.0
# Inserting review_id: 4444, movie_id: 34041, thumbsTot: 11.0, thumbsUp: 5.0
# Inserting review_id: 4445, movie_id: 34041, thumbsTot: 9.0, thumbsUp: 4.0
# Inserting review_id: 4445, movie_id: 34041, thumbsTot: 9.0, thumbsUp: 4.0
# Inserting review_id: 4446, movie_id: 34041, thumbsTot: 16.0, thumbsUp: 7.0
# Inserting review_id: 4446, movie_id: 34041, thumbsTot: 16.0, thumbsUp: 7.0
# Inserting review_id: 4447, movie_id: 34041, thumbsTot: 7.0, thumbsUp: 3.0
# Inserting review_id: 4447, movie_id: 34041, thumbsTot: 7.0, thumbsUp: 3.0
# Inserting review_id: 4448, movie_id: 34041, thumbsTot: 7.0, thumbsUp: 3.0
# Inserting review_id: 4448, movie_id: 34041, thumbsTot: 7.0, thumbsUp: 3.0
# Inserting review_id: 4449, movie_id: 34041, thumbsTot: 31.0, thumbsUp: 13.0
# Inserting review_id: 4449, movie_id: 34041, thumbsTot: 31.0, thumbsUp: 13.0
# Inserting review_id: 4450, movie_id: 34041, thumbsTot: 20.0, thumbsUp: 8.0
# Inserting review_id: 4450, movie_id: 34041, thumbsTot: 20.0, thumbsUp: 8.0
# Inserting review_id: 4451, movie_id: 34041, thumbsTot: 15.0, thumbsUp: 6.0
# Inserting review_id: 4451, movie_id: 34041, thumbsTot: 15.0, thumbsUp: 6.0
# Inserting review_id: 4452, movie_id: 34041, thumbsTot: 10.0, thumbsUp: 4.0
# Inserting review_id: 4452, movie_id: 34041, thumbsTot: 10.0, thumbsUp: 4.0
# Inserting review_id: 4453, movie_id: 34041, thumbsTot: 10.0, thumbsUp: 4.0
# Inserting review_id: 4453, movie_id: 34041, thumbsTot: 10.0, thumbsUp: 4.0
# Inserting review_id: 4454, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 4454, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 4455, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 4455, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 2.0
# Inserting review_id: 4456, movie_id: 34041, thumbsTot: 16.0, thumbsUp: 6.0
# Inserting review_id: 4456, movie_id: 34041, thumbsTot: 16.0, thumbsUp: 6.0
# Inserting review_id: 4457, movie_id: 34041, thumbsTot: 6.0, thumbsUp: 2.0
# Inserting review_id: 4457, movie_id: 34041, thumbsTot: 6.0, thumbsUp: 2.0
# Inserting review_id: 4458, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4458, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4459, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4459, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4460, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4460, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4461, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4461, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4462, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4462, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4463, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4463, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4464, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4464, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4465, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4465, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4466, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4466, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4467, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4467, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4468, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4468, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4469, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4469, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4470, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4470, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4471, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4471, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 1.0
# Inserting review_id: 4472, movie_id: 34041, thumbsTot: 20.0, thumbsUp: 6.0
# Inserting review_id: 4472, movie_id: 34041, thumbsTot: 20.0, thumbsUp: 6.0
# Inserting review_id: 4473, movie_id: 34041, thumbsTot: 7.0, thumbsUp: 2.0
# Inserting review_id: 4473, movie_id: 34041, thumbsTot: 7.0, thumbsUp: 2.0
# Inserting review_id: 4474, movie_id: 34041, thumbsTot: 7.0, thumbsUp: 2.0
# Inserting review_id: 4474, movie_id: 34041, thumbsTot: 7.0, thumbsUp: 2.0
# Inserting review_id: 4475, movie_id: 34041, thumbsTot: 7.0, thumbsUp: 2.0
# Inserting review_id: 4475, movie_id: 34041, thumbsTot: 7.0, thumbsUp: 2.0
# Inserting review_id: 4476, movie_id: 34041, thumbsTot: 15.0, thumbsUp: 4.0
# Inserting review_id: 4476, movie_id: 34041, thumbsTot: 15.0, thumbsUp: 4.0
# Inserting review_id: 4477, movie_id: 34041, thumbsTot: 23.0, thumbsUp: 6.0
# Inserting review_id: 4477, movie_id: 34041, thumbsTot: 23.0, thumbsUp: 6.0
# Inserting review_id: 4478, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4478, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4479, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4479, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4480, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4480, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4481, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4481, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4482, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4482, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4483, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4483, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4484, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4484, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4485, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4485, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4486, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4486, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4487, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4487, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 1.0
# Inserting review_id: 4488, movie_id: 34041, thumbsTot: 22.0, thumbsUp: 5.0
# Inserting review_id: 4488, movie_id: 34041, thumbsTot: 22.0, thumbsUp: 5.0
# Inserting review_id: 4489, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4489, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4490, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4490, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4491, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4491, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4492, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4492, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4493, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4493, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4494, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4494, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4495, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4495, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4496, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4496, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4497, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4497, movie_id: 34041, thumbsTot: 5.0, thumbsUp: 1.0
# Inserting review_id: 4498, movie_id: 34041, thumbsTot: 12.0, thumbsUp: 2.0
# Inserting review_id: 4498, movie_id: 34041, thumbsTot: 12.0, thumbsUp: 2.0
# Inserting review_id: 4499, movie_id: 34041, thumbsTot: 6.0, thumbsUp: 1.0
# Inserting review_id: 4499, movie_id: 34041, thumbsTot: 6.0, thumbsUp: 1.0
# Inserting review_id: 4500, movie_id: 34041, thumbsTot: 6.0, thumbsUp: 1.0
# Inserting review_id: 4500, movie_id: 34041, thumbsTot: 6.0, thumbsUp: 1.0
# Inserting review_id: 4501, movie_id: 34041, thumbsTot: 6.0, thumbsUp: 1.0
# Inserting review_id: 4501, movie_id: 34041, thumbsTot: 6.0, thumbsUp: 1.0
# Inserting review_id: 4502, movie_id: 34041, thumbsTot: 6.0, thumbsUp: 1.0
# Inserting review_id: 4502, movie_id: 34041, thumbsTot: 6.0, thumbsUp: 1.0
# Inserting review_id: 4503, movie_id: 34041, thumbsTot: 6.0, thumbsUp: 1.0
# Inserting review_id: 4503, movie_id: 34041, thumbsTot: 6.0, thumbsUp: 1.0
# Inserting review_id: 4504, movie_id: 34041, thumbsTot: 8.0, thumbsUp: 1.0
# Inserting review_id: 4504, movie_id: 34041, thumbsTot: 8.0, thumbsUp: 1.0
# Inserting review_id: 4505, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4505, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4506, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4506, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4507, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4507, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4508, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 0.0
# Inserting review_id: 4508, movie_id: 34041, thumbsTot: 4.0, thumbsUp: 0.0
# Inserting review_id: 4509, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 4509, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 4510, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4510, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4511, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4511, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4512, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4512, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4513, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4513, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4514, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4514, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4515, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4515, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4516, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 4516, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 4517, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4517, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4518, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4518, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4519, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4519, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4520, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4520, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4521, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 0.0
# Inserting review_id: 4521, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 0.0
# Inserting review_id: 4522, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 4522, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 4523, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 0.0
# Inserting review_id: 4523, movie_id: 34041, thumbsTot: 3.0, thumbsUp: 0.0
# Inserting review_id: 4524, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4524, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4525, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 4525, movie_id: 34041, thumbsTot: 2.0, thumbsUp: 0.0
# Inserting review_id: 4526, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4526, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4527, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4527, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4528, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4528, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4529, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4529, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4530, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4530, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4531, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4531, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4532, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4532, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4533, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4533, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4534, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4534, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4535, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4535, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4536, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4536, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4537, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4537, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4538, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4538, movie_id: 34041, thumbsTot: 1.0, thumbsUp: 0.0
# Inserting review_id: 4539, movie_id: 34041, thumbsTot: nan, thumbsUp: nan
# Error on row 5795: bigint out of range
#
# ('review_id', 'integer')
# ('movie_id', 'bigint')
# ('thumbsup', 'bigint')
# ('totalthumbs', 'bigint')
# ('posemo', 'double precision')
# ('negemo', 'double precision')
# ('reviewscore', 'double precision')
# ('url', 'text')
# ('rev', 'text')
# Data inserted and schema retrieved successfully!
